# %% [markdown]
# <center><h1>Implementing of Wang-Mendel method<br>in Python</h1></center>

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
from fuzzy.datatype import DataTable
import fuzzy.input_space.memberfuncs as mfs
from fuzzy.input_space import discourse
from fuzzy.inference import rules, antecedent, consequent, aggregator, defuzzification
from fuzzy.system.inferece_system import InferenceSystem
from fuzzy.system import anfis
from fuzzy.utilies import report
import wang_mendel.trainer

# %% [markdown]
# <h3>Define Fuzzy Inference  System (FIS) and their sets</h3>

# %%
fuzzy_system = InferenceSystem(
    input_domain = discourse.Domain(
        discourse.Discourse(
            mfs.Trapezoidal(rhead=-5, rbase=-3.333),
            mfs.Triangular(-5, -3.333, -1.666),
            mfs.Triangular(-3.333, -1.666, 0),
            mfs.Triangular(-1.666, 0, 1.666),
            mfs.Triangular(0, 1.666, 3.333),
            mfs.Triangular(1.666, 3.333, 5),
            mfs.Trapezoidal(3.333, 5)
        ),
        discourse.Discourse(
            mfs.Trapezoidal(rhead=-5, rbase=-3.333),
            mfs.Triangular(-5, -3.333, -1.666),
            mfs.Triangular(-3.333, -1.666, 0),
            mfs.Triangular(-1.666, 0, 1.666),
            mfs.Triangular(0, 1.666, 3.333),
            mfs.Triangular(1.666, 3.333, 5),
            mfs.Trapezoidal(3.333, 5)
        )
    ),
    aggregator = aggregator.Max(),
    defuzzifier = defuzzification.CoA(
        discourse.Discourse(
            mfs.Trapezoidal(rhead=0, rbase=8.333),
            mfs.Triangular(0, 8.333, 16.666),
            mfs.Triangular(8.333, 16.666, 25),
            mfs.Triangular(16.666, 25, 33.333),
            mfs.Triangular(25, 33.333, 41.666),
            mfs.Triangular(33.333, 41.666, 50),
            mfs.Trapezoidal(41.666, 50)
        )
    )
)

# %% [markdown]
# <h3>Plotting sets of the FIS</h3>

# %%
set_names = ['INPUT SET 1', 'INPUT SET 2', 'OUTPUT SET']
inputs=[np.linspace(-7, 7, 1000), np.linspace(-7, 7, 1000), np.linspace(-10, 60, 1000)]
outputs=[np.array([dis(x) for x in input]).T for dis, input in zip(fuzzy_system.input_domain, inputs)]
outputs.append(np.array([fuzzy_system.defuzzifier.output_discourse(x) for x in inputs[2]]).T)

for inpt, output, name in zip(inputs, outputs, set_names):
    plt.figure(figsize=(7,2.5))
    for mfout in output:
        plt.plot(inpt, mfout)
    plt.title(name)

plt.show()

# %% [markdown]
# <h3>
#     Train the defined FIS with<br>
#     x<sub>1</sub><sup>2</sup>+x<sub>2</sub><sup>2</sup> function in range x<sub>1</sub>[-5, 5], x<sub>2</sub>[-5, 5]<br>
#     with 1681 data
# </h3>

# %%
input_range = np.linspace(-5, 5, 41).tolist()
train_data = DataTable()
train_data.inputs = [
    [x1, x2]
    for x1 in input_range
    for x2 in input_range
]
train_data.output = [
    x1 ** 2 + x2 ** 2
    for x1, x2 in train_data.inputs
]

trainer = wang_mendel.trainer.Trainer(
    input_domain = fuzzy_system.input_domain,
    output_discourse = fuzzy_system.defuzzifier.output_discourse,
    train_table = train_data,
    antecedent_type = antecedent.Product
)

fuzzy_system.rulebase = trainer.train()

# %% [markdown]
# <h3>Drawing Rule Base Table</h3>

# %%
def display_rulebase(rulebase: rules.RuleBase):
    rows_Columns_text = [str(i) for i in range(1, 8)]
    data = np.empty((7, 7), dtype = np.int32)
    for rule in rulebase:
            data[
                 rule[0].antecedent[0]
            ][
                 rule[0].antecedent[1]
            ] = fuzzy_system.defuzzifier.output_discourse[
                 rule[0].consequent()
            ].centroid
    df = pd.DataFrame(
        data, 
        index = rows_Columns_text, 
        columns = rows_Columns_text
    )
    
    plt.figure(figsize = (5, 5))  
    plt.imshow(df, cmap = 'coolwarm', aspect = 'auto') 

    for i in range(df.shape[0]):  
        for j in range(df.shape[1]):  
            plt.text(j, i, str(df.iloc[i, j]), ha = 'center', va = 'center')
    
    plt.xticks(ticks = np.arange(7), labels = rows_Columns_text, ha = 'right')
    plt.yticks(ticks = np.arange(7), labels = rows_Columns_text)
    
    plt.title("RuleBase Centroids")
    plt.xlabel("INPUT SET 2")
    plt.ylabel("INPUT SET 1")
    
    plt.tight_layout()
    plt.show()

display_rulebase(fuzzy_system.rulebase)

# %% [markdown]
# <h3>Plotting fuzzy result of the FIS related to desired result</h3>

# %%
fig = plt.figure(figsize=(10, 10))

X1, X2 = np.meshgrid(input_range, input_range)

Z = X1 ** 2 + X2 ** 2
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_wireframe(X1, X2, Z, rstride=1, cstride=1, alpha=0.5)
ax.set_title('Desired Result')

ZP = np.array([[fuzzy_system([x1, x2]) for x1 in input_range] for x2 in input_range])
axp = fig.add_subplot(1, 2, 2, projection='3d')
axp.plot_wireframe(X1, X2, ZP, rstride=1, cstride=1, alpha=0.5)
axp.set_title('Fuzzy Result')

plt.show()

# %% [markdown]
# <h3>
#     Calculating Mean Square Error of the FIS<br>
#     with 169 random data over 100 iteration for:<br>
#     <ul>
#         <li>Train data</li>
#         <li>Test data</li>
#     </ul>
# </h3>

# %%
fis_mse = report.MeanSquareError(fuzzy_system)
fis_mse.test_tables = train_data
mse_mean, mse_std = fis_mse()
print(f"Mean Square Error for train data: {mse_mean / 2:.4f}")

test_inputs = [
     np.random.uniform(-5, 5, size=(169, 2)).tolist()
     for _ in range(100)
]

test_data = [
     DataTable(
          inputs= inpts,
          output= [
               x1 ** 2 + x2 ** 2
               for x1, x2 in inpts
          ]
     )
     for inpts in test_inputs
]

fis_mse.test_tables = test_data
mse_mean, mse_std = fis_mse()
print(f"Mean Square Error for test data: {mse_mean / 2:.4f} ± {mse_std / 2:.3f}")
# Out:
# Mean Square Error for train data: 1.8978
# Mean Square Error for test data: 1.8945 ± 0.185

# %% [markdown]
# <h3>Configuring ANFIS</h3>

# %%
anfis_sys = anfis.ANFIS(
     input_domain= fuzzy_system.input_domain,
     antecedents= [
          rule[0].antecedent 
          for rule in fuzzy_system.rulebase
     ],
     consequents= [
          consequent.Sugeno(
               fuzzy_system.defuzzifier.output_discourse[
                    rule[0].consequent()
                ].centroid
          )
          for rule in fuzzy_system.rulebase
     ]
)

# %% [markdown]
# <h3>Training ANFIS</h3>

# %%
train_mses, test_mses = anfis.train(
     anfis_system= anfis_sys,
     eta= 0.01,
     epochs_no= 25,
     train_table= train_data,
     test_tables= test_data[:10]
)

plt.figure(figsize=(8, 5))
plt.plot(train_mses)
plt.plot(test_mses)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_mses, test_mses = anfis.train(
#       2      anfis_system= anfis_sys,
#       3      eta= 0.01,
#       4      epochs_no= 25,
#       5      train_table= train_data,
#       6      test_tables= test_data[:10]
#       7 )
#       9 plt.figure(figsize=(8, 5))
#      10 plt.plot(train_mses)
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\system\anfis.py:96, in train(anfis_system, eta, epochs_no, train_table, test_tables)
#      94 def train(anfis_system: ANFIS, eta, epochs_no, train_table: DataTable, test_tables = None):
#      95     train_mse = MeanSquareError(anfis_system, train_table)
# ---> 96     train_mse_list = [train_mse()[0]]
#      97     test_mse_list = []
#      98     if test_tables:
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\utilies\report.py:14, in MeanSquareError.__call__(self)
#      12 def __call__(self):
#      13     system_mse = [
# ---> 14         sum(
#      15             (actual_output - self._inference_system(inputs)) ** 2
#      16             for inputs, actual_output in data_table
#      17         ) / len(data_table)
#      18         for data_table in self._test_tables
#      19     ]
#      21     return np.mean(system_mse), np.std(system_mse)
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\utilies\report.py:15, in <genexpr>(.0)
#      12 def __call__(self):
#      13     system_mse = [
#      14         sum(
# ---> 15             (actual_output - self._inference_system(inputs)) ** 2
#      16             for inputs, actual_output in data_table
#      17         ) / len(data_table)
#      18         for data_table in self._test_tables
#      19     ]
#      21     return np.mean(system_mse), np.std(system_mse)
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\system\anfis.py:77, in ANFIS.__call__(self, *args)
#      75 weigths = self._antecedent_layer(input_domain_grades)
#      76 norm_weigths = self._normalize_layer(weigths)
# ---> 77 return sum(self._consequent_layer(norm_weigths, *args))
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\system\anfis.py:89, in ANFIS._consequent_layer(self, norm_weigths, *args)
#      87 def _consequent_layer(self, norm_weigths: list[float], *args):
#      88     return [
# ---> 89         norm_weigth * f(*args)
#      90         for norm_weigth, f in zip(norm_weigths, self._consequents)
#      91     ]
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\inference\consequent.py:84, in Sugeno.__call__(self, *args)
#      83 def __call__(self, *args):
# ---> 84     inputs = self._get_inputs(*args)
#      85     return sum(co * x for co, x in zip(self._coefficients, inputs))
#
# File E:\Projects\Python\Fuzzy Inference System\fuzzy\inference\consequent.py:105, in Sugeno._get_inputs(self, *args)
#     103 elif isinstance(args[0], list):
#     104     if len(args[0]) > (len(self._coefficients) - 1):
# --> 105         raise ValueError(f"Must pass {len(self._coefficients) - 1} inputs to function")
#     106     if not all(isinstance(num, int) or isinstance(num, float) for num in args[0]):
#     107         raise TypeError("All elements in list must be integer or float")
#
# ValueError: Must pass 0 inputs to function

# %% [markdown]
# <hr>
# <b>
#     Habib Ghanizadeh<br>
#     Student No: 403066457<br>
#     mail: <a href="mailto:h.a.ghanizadeh@gmail.com">h.a.ghanizadeh@gmail.com</a>
# </b>
